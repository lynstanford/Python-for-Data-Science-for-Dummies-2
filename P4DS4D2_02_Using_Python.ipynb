# %% [markdown]
# # Working with Python

# %% [markdown]
# ## Getting a taste of the language

# %%
print "Hello There!"
# Out:
#   File "<ipython-input-1-fe18535d9681>", line 1
#     print "Hello There!"
#                        ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello There!")?

# %%
print("Hello There!")
# Out:
# Hello There!

# %% [markdown]
# ## Understanding the need for indentation

# %%
if 1 < 2:
   print("1 is less than 2")
# Out:
# 1 is less than 2
